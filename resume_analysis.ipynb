# %%
import pandas as pd

df = pd.read_csv('job_roles.csv')

df.head()
# Out:
#                     Category  \
# 0  Network Security Engineer
# 1           Python Developer
# 2              SAP Developer
# 3           Python Developer
# 4                   Database
#
#                                               Resume
# 0  technical expertise â cisco asa checkpoint fir...
# 1  education details june to june diploma compute...
# 2  competencies sap business intelligence version...
# 3  â operating systems windows â others ms excel ...
# 4  technical expertise operating systems microsof...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

counts = df['Category'].value_counts()
labels = df['Category'].unique()
plt.figure(figsize=(15,7))
plt.pie(counts, labels=labels, autopct='%1.1f%%',)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x = df['Category'], palette="Set2")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\syeds\AppData\Local\Temp\ipykernel_528\1072610488.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df['Category'], palette="Set2")

# %%
df['Category'].value_counts()
# Out:
# Category
# Network Security Engineer    84
# Mechanical Engineer          84
# DotNet Developer             84
# Business Analyst             84
# ETL Developer                84
# Java Developer               84
# HR                           84
# Hadoop                       84
# Sales                        84
# DevOps Engineer              84
# Data Science                 84
# Civil Engineer               84
# Testing                      84
# Python Developer             84
# Advocate                     84
# Automation Testing           84
# Web Designing                84
# Blockchain                   84
# PMO                          84
# Arts                         84
# Health and fitness           84
# Electrical Engineering       84
# Database                     84
# SAP Developer                84
# Operations Manager           84
# Name: count, dtype: int64

# %%
import re

def clean_text(text):
    text = text.lower()
    # Remove numbers and special characters
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

df['Resume'] = df['Resume'].apply(lambda x: clean_text(x))

# %%
df.head()
# Out:
#                     Category  \
# 0  Network Security Engineer
# 1           Python Developer
# 2              SAP Developer
# 3           Python Developer
# 4                   Database
#
#                                               Resume
# 0  technical expertise â cisco asa checkpoint fir...
# 1  education details june to june diploma compute...
# 2  competencies sap business intelligence version...
# 3  â operating systems windows â others ms excel ...
# 4  technical expertise operating systems microsof...
